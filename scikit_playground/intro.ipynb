# %%
from sklearn.datasets import fetch_california_housing
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# return_X_y=True returns data and target as numpy arrays (ie x and y axis)
data = fetch_california_housing()
X = data.data
y = data.target

# %%
# get info about the dataset
print(X.shape)
print(y.shape)
print(fetch_california_housing().DESCR)

# %%
# Histogram
med_income = X[:, data.feature_names.index('MedInc')]  # Indexing the median income column

plt.hist(med_income, bins=100, color='blue', alpha=0.7)
plt.title('Distribution of Median Income')
plt.xlabel('Median Income (tens of thousands of USD)')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot
median_house_value = y
# alpha has to do with transparency and can help with overplotting and making the plot more readable
plt.scatter(med_income, median_house_value, color='blue', alpha=0.1)
plt.title('Median Income vs Median House Value')
plt.xlabel('Median Income (tens of thousands of USD)')
plt.ylabel('Median House Value (USD)')
plt.show()

# %%
# Correlation matrix: how much each feature correlates with each other

# Create a dataframe from the data
df = pd.DataFrame(data.data, columns=data.feature_names)
df['MedianHouseValue'] = data.target

correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Variables')
plt.show()
